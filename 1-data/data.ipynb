# %% [markdown]
# # Part 1 - Loading Data
# ---
# ### Papers Past Topic Modeling
# <br/>
#
# Ben Faulks - bmf43@uclive.ac.nz
#
# Xiandong Cai - xca24@uclive.ac.nz
#
# Yujie Cui - ycu23@uclive.ac.nz

# %%
import glob, os, subprocess
from pprint import pprint
import pandas as pd

# %%
# for plot
import matplotlib.pyplot as plt
plt.style.use('seaborn-darkgrid')
# %matplotlib inline

# %%
# for PySpark
import findspark
import pyspark
from pyspark import SparkContext, SparkConf
from pyspark.sql import functions as F
from pyspark.sql.types import *
from pyspark.sql.session import SparkSession

# %% [markdown]
# ## 1 The Papers Past Dataset

# %%
# set path of raw data
path = r'../data/papers_past'

# %% [markdown]
# **Check total dataset directory size:**

# %%
print('Total size:', subprocess.check_output(['du','-sh', path]).split()[0].decode('utf-8'))
# Out:
# Total size: 33G

# %% [markdown]
# **Check dataset files path and size:**

# %%
def convert_bytes(num):
    """
    this function will convert bytes to MB.... GB... etc
    """
    for x in ['bytes', 'KB', 'MB', 'GB', 'TB']:
        if num < 1024.0:
            return "%3.1f %s" % (num, x)
        num /= 1024.0


def file_size(file_path):
    """
    this function will return the file size
    """
    if os.path.isfile(file_path):
        file_info = os.stat(file_path)
        return convert_bytes(file_info.st_size)


# Check the file size
def print_size(flies):
    """
    this function will print the file size of a file list
    """
    i = 1
    for file in files:
        print(i, file,file_size(file))
        i += 1

        
files = glob.glob(path + '/*.txt')
print_size(files)
# Out:
# 1 ../data/papers_past/Poverty Bay Herald.txt 1.2 GB
# 2 ../data/papers_past/Manawatu Standard.txt 133.1 MB
# 3 ../data/papers_past/Oxford Observer.txt 18.1 MB
# 4 ../data/papers_past/Tuapeka Times.txt 343.7 MB
# 5 ../data/papers_past/Mataura Ensign.txt 171.3 MB
# 6 ../data/papers_past/Bruce Herald.txt 300.1 MB
# 7 ../data/papers_past/Ohinemuri Gazette.txt 246.6 MB
# 8 ../data/papers_past/Nelson Examiner and New Zealand Chronicle.txt 223.2 MB
# 9 ../data/papers_past/NZ Truth.txt 292.3 MB
# 10 ../data/papers_past/Hawke's Bay Weekly Times.txt 5.1 MB
# 11 ../data/papers_past/New Zealand Illustrated Magazine.txt 8.8 MB
# 12 ../data/papers_past/Rodney and Otamatea Times, Waitemata and Kaipara Gazette.txt 125.5 MB
# 13 ../data/papers_past/Southland Times.txt 531.5 MB
# 14 ../data/papers_past/Thames Star.txt 710.1 MB
# 15 ../data/papers_past/Wanganui Herald.txt 791.9 MB
# 16 ../data/papers_past/Daily Southern Cross.txt 796.9 MB
# 17 ../data/papers_past/Waiapu Church Gazette.txt 29.6 MB
# 18 ../data/papers_past/Wellington Independent.txt 278.4 MB
# 19 ../data/papers_past/Inangahua Times.txt 146.6 MB
# 20 ../data/papers_past/Otago Witness.txt 1.1 GB
# 21 ../data/papers_past/Ashburton Guardian.txt 882.2 MB
# 22 ../data/papers_past/Bush Advocate.txt 178.4 MB
# 23 ../data/papers_past/Bay Of Plenty Times.txt 403.4 MB
# 24 ../data/papers_past/Daily Telegraph.txt 456.1 MB
# 25 ../data/papers_past/Akaroa Mail and Banks Peninsula Advertiser.txt 198.2 MB
# 26 ../data/papers_past/New Zealand Gazette and Wellington Spectator.txt 20.9 MB
# 27 ../data/papers_past/Ellesmere Guardian.txt 342.0 MB
# 28 ../data/papers_past/Marlborough Express.txt 1.1 GB
# 29 ../data/papers_past/Star.txt 724.6 MB
# 30 ../data/papers_past/Lyttelton_Times.txt 115.6 MB
# 31 ../data/papers_past/Hawera & Normanby Star.txt 1.3 GB
# 32 ../data/papers_past/Grey River Argus.txt 946.6 MB
# 33 ../data/papers_past/Clutha Leader.txt 245.5 MB
# 34 ../data/papers_past/Wanganui Chronicle.txt 1.3 GB
# 35 ../data/papers_past/Fair Play.txt 3.0 MB
# 36 ../data/papers_past/Te Aroha News.txt 80.2 MB
# 37 ../data/papers_past/New Zealand Colonist and Port Nicholson Advertiser.txt 6.4 MB
# 38 ../data/papers_past/Auckland Star.txt 1.2 GB
# 39 ../data/papers_past/North Otago Times.txt 724.2 MB
# 40 ../data/papers_past/New Zealand Spectator and Cook's Strait Guardian.txt 67.7 MB
# 41 ../data/papers_past/Nelson Evening Mail.txt 546.8 MB
# 42 ../data/papers_past/New Zealand Free Lance.txt 43.5 MB
# 43 ../data/papers_past/Manawatu Herald.txt 107.0 MB
# 44 ../data/papers_past/Otago Daily Times.txt 2.4 GB
# 45 ../data/papers_past/Progress.txt 6.4 MB
# 46 ../data/papers_past/Taranaki Daily News.txt 57.6 MB
# 47 ../data/papers_past/Feilding Star.txt 823.5 MB
# 48 ../data/papers_past/Waimate Daily Advertiser.txt 9.1 MB
# 49 ../data/papers_past/Colonist.txt 970.4 MB
# 50 ../data/papers_past/New Zealand Tablet.txt 214.4 MB
# 51 ../data/papers_past/New Zealand Advertiser and Bay of Islands Gazette.txt 524.3 KB
# 52 ../data/papers_past/Hawke's Bay Herald.txt 424.6 MB
# 53 ../data/papers_past/Hutt News.txt 31.6 MB
# 54 ../data/papers_past/Kaipara and Waitemata Echo.txt 29.8 MB
# 55 ../data/papers_past/Waikato Times.txt 171.3 MB
# 56 ../data/papers_past/New Zealander.txt 42.7 MB
# 57 ../data/papers_past/Northern Advocate.txt 406.3 MB
# 58 ../data/papers_past/Timaru Herald.txt 474.8 MB
# 59 ../data/papers_past/Albertland Gazette.txt 266.6 KB
# 60 ../data/papers_past/Evening Post.txt 5.9 GB
# 61 ../data/papers_past/Manawatu Times.txt 78.3 MB
# 62 ../data/papers_past/Observer.txt 245.2 MB
# 63 ../data/papers_past/Otautau Standard and Wallace County Chronicle.txt 93.7 MB
# 64 ../data/papers_past/West Coast Times.txt 676.4 MB
# 65 ../data/papers_past/Waiapu Church Times.txt 485.0 KB
# 66 ../data/papers_past/Taranaki Herald.txt 602.1 MB
# 67 ../data/papers_past/Kai Tiaki.txt 1.5 MB
# 68 ../data/papers_past/Wairarapa Daily Times.txt 602.9 MB

# %% [markdown]
# **Check total samples/rows/documents of the dataset:**

# %%
# list of each file line number
lines = [sum(1 for line in open(f)) for f in files] 

print('Total sample number:', sum(lines))
# Out:
# Total sample number: 16731578

# %% [markdown]
# **Visualize the dataset based on the file/publisher:**

# %%
# list of each file name
names = [os.path.splitext(os.path.basename(f))[0] for f in files] 
# dictionary of each file path and line number
info = dict(zip(names, lines)) 

# transform dict of dataset files to dataframe for statistic and ploting.
df_info = pd.DataFrame.from_dict(info, orient='index').reset_index()
df_info.columns = ['publisher', 'lines']
df_info = df_info.sort_values('lines', ascending=False).reset_index(drop=True)
df_info.T
# Out:
#                      0                       1                   2   \
# publisher  Evening Post  Hawera & Normanby Star  Wanganui Chronicle
# lines           3007465                  807068              804226
#
#                           3                    4              5   \
# publisher  Otago Daily Times  Marlborough Express  Auckland Star
# lines                 747706               711069         674134
#
#                            6         7                   8                 9   \
# publisher  Poverty Bay Herald  Colonist  Ashburton Guardian  Grey River Argus
# lines                  643505    638055              603346            574017
#
#                   ...                                58  \
# publisher         ...          Waimate Daily Advertiser
# lines             ...                              5037
#
#                                          59        60  \
# publisher  New Zealand Illustrated Magazine  Progress
# lines                                  4201      3216
#
#                                  61  \
# publisher  Hawke's Bay Weekly Times
# lines                          1690
#
#                                                           62         63  \
# publisher  New Zealand Colonist and Port Nicholson Advert...  Kai Tiaki
# lines                                                   1650       1630
#
#                   64                   65  \
# publisher  Fair Play  Waiapu Church Times
# lines           1180                  245
#
#                                                           66  \
# publisher  New Zealand Advertiser and Bay of Islands Gazette
# lines                                                    184
#
#                            67
# publisher  Albertland Gazette
# lines                     112
#
# [2 rows x 68 columns]

# %%
# split to plot better
# index of half dataframe
i = int(df_info.shape[0]/2)
# first half
df_info_1 = df_info.iloc[:i]
# second half
df_info_2 = df_info.iloc[i:]

# plot
fig, axes = plt.subplots(nrows=2, ncols=1, figsize=(14, 20))
fig.subplots_adjust(hspace=0.4)
df_info_1.plot(ax=axes[0], kind='bar', x='publisher', y='lines', legend=False)
df_info_2.plot(ax=axes[1], kind='bar', x='publisher', y='lines', legend=False)
axes[0].set_title('Document Number of Each File/Publisher')
axes[0].set_ylabel('Document Number')
axes[0].set_xlabel('File/Publisher')
axes[1].set_ylabel('Document Number')
axes[1].set_xlabel('File/Publisher')
# Out:
# Text(0.5, 0, 'File/Publisher')

# %% [markdown]
# **The Papers Past dataset has:**
# * total 33 GB,
# * total 68 files,
# * total 16,731,578 lines(samples),
# * each file contains lines from 3,007,465 (Evening Post) to 112 (Albertland Gazette).

# %% [markdown]
# ## 2 Loading Dataset With PySpark

# %% [markdown]
# **For 33 GB dataset, we chose using PySpark as our data process plateform.**

# %%
findspark.init()
# start a Spark context and session
conf = SparkConf()
conf.setAppName('local')
conf.set('spark.driver.cores', 6) # set processor number
conf.set('spark.driver.memory', '62g') # set memory size
conf.set('spark.driver.maxResultSize', '4g')

try:
    sc.stop()
    sc = SparkContext(conf=conf)
except:
    sc = SparkContext(conf=conf)

# passing spark context ot sql module
spark = SparkSession(sc)

# print configurations
pprint(spark.sparkContext._conf.getAll())

# check context
sc
# Out:
# [('spark.driver.port', '32878'),
#  ('spark.app.name', 'local'),
#  ('spark.rdd.compress', 'True'),
#  ('spark.serializer.objectStreamReset', '100'),
#  ('spark.driver.host', '192.168.1.207'),
#  ('spark.driver.memory', '62g'),
#  ('spark.master', 'local[*]'),
#  ('spark.executor.id', 'driver'),
#  ('spark.submit.deployMode', 'client'),
#  ('spark.app.id', 'local-1547614337303'),
#  ('spark.ui.showConsoleProgress', 'true'),
#  ('spark.driver.cores', '6'),
#  ('spark.driver.maxResultSize', '4g')]
# <SparkContext master=local[*] appName=local>

# %% [markdown]
# **Load dataset:**

# %%
path = r'../../data/papers_past'

data_schema = StructType([
    StructField('id', IntegerType()),
    StructField('url', StringType()),
    StructField('publisher', StringType()),
    StructField('time', StringType()),
    StructField('title', StringType()),
    StructField('content', StringType())
])

df = (
    spark.read.format("com.databricks.spark.csv")
    .option("header", "false")
    .option("inferSchema", "false")
    .option("delimiter", "\t")
    .schema(data_schema)
    .load(path)
)

# %% [markdown]
# **Print random rows of the loaded dataframe, and check row number of the loaded dataframe:**

# %%
df.sample(False, 0.00001).limit(20).show()
print('Shape of dataframe: ({}, {})'.format(df.count(), len(df.columns)))
# Out:
# +--------+--------------------+------------------+--------------------+--------------------+--------------------+
# |      id|                 url|         publisher|                time|               title|             content|
# +--------+--------------------+------------------+--------------------+--------------------+--------------------+
# |15146314|http://api.digita...|Poverty Bay Herald|1912-04-06T00:00:...|ST. MARY'S CHURCH...|ST. MARY'S CHURCH...|
# |16721715|http://api.digita...|Poverty Bay Herald|1918-02-18T00:00:...|TOWN EDITION. (Po...|TOWN EDITION.At t...|
# | 4786831|http://api.digita...|Poverty Bay Herald|1882-03-10T00:00:...|BERLIN. (Poverty ...|b'BERLIN.March 8....|
# | 2969269|http://api.digita...|     Tuapeka Times|1888-08-18T00:00:...|Misunderstood. (T...|Misunderstood.He ...|
# | 4814290|http://api.digita...|     Tuapeka Times|1879-06-11T00:00:...|Page 3 Advertisem...|this suggestion H...|
# | 2072832|http://api.digita...|      Bruce Herald|1872-12-18T00:00:...|Untitled (Bruce H...|•o(To the Editor....|
# | 2187626|http://api.digita...|      Bruce Herald|1874-12-22T00:00:...|Cricket. (Bruce H...|Cricket.5 ■ w MAR...|
# | 6230271|http://api.digita...|      Bruce Herald|1897-08-20T00:00:...|Various Brides. (...|Various Brides.In...|
# | 6642137|http://api.digita...|      Bruce Herald|1899-06-16T00:00:...|WONDERFUL OLD WOM...|WONDERFUL OLD WOM...|
# | 3022996|http://api.digita...|          NZ Truth|1909-02-20T00:00:...|ANSWERS TO CORRES...|ANSWERS TO CORRES...|
# | 6283778|http://api.digita...|          NZ Truth|1924-10-25T00:00:...|Untitled Illustra...|                null|
# | 7243766|http://api.digita...|          NZ Truth|1927-12-29T00:00:...|GIVES PROMISE (NZ...|GIVES PROMISE| DE...|
# | 4628200|http://api.digita...|   Southland Times|1874-11-11T00:00:...|Page 1 Advertisem...|Boiiaeii Motices....|
# | 9317242|http://api.digita...|   Southland Times|1886-02-09T00:00:...|Page 4 Advertisem...|Watchmakers. The ...|
# |11794129|http://api.digita...|       Thames Star|1899-07-29T00:00:...|BURNED TO DEATH. ...|BURNED TO DEATH.S...|
# |15385506|http://api.digita...|       Thames Star|1912-11-27T00:00:...|Page 2 Advertisem...|• 4w^ MENS SUITS ...|
# |16431747|http://api.digita...|       Thames Star|1917-08-15T00:00:...|MR HENDERSON'S SU...|MR HENDERSON'S SU...|
# |16628018|http://api.digita...|       Thames Star|1919-06-10T00:00:...|SOLDIER'S WILLS (...|SOLDIER'S WILLSWE...|
# |10456274|http://api.digita...|   Wanganui Herald|1893-09-06T00:00:...|METEOROLOGICAL RE...|METEOROLOGICAL RE...|
# |11622585|http://api.digita...|   Wanganui Herald|1896-05-12T00:00:...|FIRE BRIGADE CHAR...|FIRE BRIGADE CHAR...|
# +--------+--------------------+------------------+--------------------+--------------------+--------------------+
#
# Shape of dataframe: (16731578, 6)

# %% [markdown]
# ---
